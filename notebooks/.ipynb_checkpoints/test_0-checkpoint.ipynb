# %% [markdown]
# # Initial test of jupyter

# %%
# we need this to get the plots to be inline
# %matplotlib inline

# %% [markdown]
# ## this is a sub-heading

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 50, 1000)
y = np.sin((x/(2*np.pi))**2)

# %% [markdown]
# This is a markdown line without formatting

# %%
plt.plot(x, y-5)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
ax1.plot(x,y)
ax2.plot(x, y/2)
